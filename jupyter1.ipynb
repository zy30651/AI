# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 8), dpi = 100)
plt.plot([1,2,3], [4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# 生成flg，并设置图片大小，清晰度
plt.figure(figsize=(20, 8), dpi=80)
# 准备数据
plt.plot([1,2,3,4,5,6,7],[17,18,19,11,14,20,11])
# show
plt.show()
# 设置图片保存位置
plt.savefig("test.png")
